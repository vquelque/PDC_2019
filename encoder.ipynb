# %%
import bitarray
import random
import string
import numpy as np

# %%
N = 160
ba = bitarray.bitarray()
text = 'Bonjour, je suis le message a transmettre'
print(text)
ba.frombytes(text.encode('utf-8'))
array = np.array(ba.tolist()).astype(int)
print(ba)
# Out:
# Bonjour, je suis le message a transmettre
# bitarray('')
